# %%
import folium
import pandas as pd
import csv
import json

# 부산 지도 만들기
busan_map =folium.Map(location=[35.17944,129.07556], tiles='Stamen Terrain', zoom_start=14)

busan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77f675f494e3531d95ad579317e5ae7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77f675f494e3531d95ad579317e5ae7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77f675f494e3531d95ad579317e5ae7c = L.map(
#                 &quot;map_77f675f494e3531d95ad579317e5ae7c&quot;,
#                 {
#                     center: [35.17944, 129.07556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65cfbf5140894fd356ce1d56710fd99a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77f675f494e3531d95ad579317e5ae7c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 시장 리스트를 데이터 프레임으로 변환

market_high_df = pd.read_excel('./market_list_high.xlsx', engine = "openpyxl")
market_low_df = pd.read_excel('./market_list_low.xlsx', engine = "openpyxl")
subway_df = pd.read_excel('./market_subway_list.xlsx', engine = "openpyxl")
top_20_df = pd.read_excel('./Busan_location.xlsx', engine = "openpyxl")

# %%
# 시장, 지하철 위치 정보를 마커로 표시, top20 표시

for name, lat, lng in zip(market_high_df.시장명, market_high_df.위도, market_high_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=150),
                  icon=folium.Icon(color='pink',icon='basket-shopping', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(market_low_df.시장명, market_low_df.위도, market_low_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=150),
                  icon=folium.Icon(color='lightgray',icon='basket-shopping', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(subway_df.역명, subway_df.위도, subway_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=50, max_width=100),
                  icon=folium.Icon(color='lightgreen',icon='train-subway', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(top_20_df.시장명, top_20_df.위도, top_20_df.경도):
    folium.CircleMarker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=100),
                  radius=10, color='black').add_to(busan_map)
    
busan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77f675f494e3531d95ad579317e5ae7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77f675f494e3531d95ad579317e5ae7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77f675f494e3531d95ad579317e5ae7c = L.map(
#                 &quot;map_77f675f494e3531d95ad579317e5ae7c&quot;,
#                 {
#                     center: [35.17944, 129.07556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65cfbf5140894fd356ce1d56710fd99a = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77f675f494e3531d95ad579317e5ae7c);
#
#
#             var marker_c89dd1cb320bb237f129d9e0d42b4f05 = L.marker(
#                 [35.1127693, 128.9316607],
#                 {}
#             ).addTo(map_77f675f494e3531d95ad579317e5ae7c);
#
#
#             var icon_3611cc510c3750572e8827d36cb2583e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c89dd1cb320bb237f129d9e0d42b4f05.setIcon(icon_3611cc510c3750572e8827d36cb2583e);
#
#
#         var popup_5cbd1ca9279ed98143aa293ce5fb7b01 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_850dbf9023987f3ba3d37dbe1a985a57 = $(`&lt;div id=&quot;html_850dbf9023987f3ba3d37dbe1a985a57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;명지시장&lt;/div&gt;`)[0];
#                 popup_5cbd1ca9279ed98143aa293ce5fb7b01.setContent(html_850dbf9023987f3ba3d37dbe1a985a57);
#
#
#
#         marker_c89dd1cb320bb237f129d9e0d42b4f05.bindPopup(popup_5cbd1ca9279ed98143aa293ce5fb7b01)
#         ;
#
#
#
#
#             var marker_29d072a4309c632080b49f615bf6566f = L.marker(
#                 [35.0966394, 129.0305933],
#                 {}
#             ).addTo(map_77f675f494e3531d95ad579317e5ae7c);
#
#
#             var icon_13953db61552e54ad36ceab17c9932af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_29d072a4309c632080b49f615bf6566f.setIcon(icon_13953db61552e54ad36ceab17c9932af);
#
#
#         var popup_21fa12fb801a9992f23ac7e6a3ce52a2 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_ef6090d3702c8e24d23f67aaad095e9f = $(`&lt;div id=&quot;html_ef6090d3702c8e24d23f67aaad095e9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;자갈치시장&lt;/div&gt;`)[0];
#                 popup_21fa12fb801a9992f23ac7e6a3ce52a2.setContent(html_ef6090d3702c8e24d23f67aaad095e9f);
#
#
#
#         marker_29d072a4309c632080b49f615bf6566f.bindPopup(popup_21fa12fb801a9992f23ac7e6a3ce52a2)
#         ;
#
#
#
#
#             var marker_590add03bf00156d4a3dd98c7a6ce223 = L.marker(
#                 [35.1416917, 129.0606173],
#                 {}
#             ).addTo(map_77f675f494e3531d95ad579317e5ae7c);
#
#
#             var icon_688da5ca70f263433a92a1853ee42634 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_590add03bf00156d4a3dd98c7a6ce223.setIcon(icon_688da5ca70f263433a92a1853ee42634);
#
#
#         var popup_6ab90ae6d92fce78e02318e1aaae1d93 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_b58cc17c0615213f4c602d12dac1ad04 = $(`&lt;div id=&quot;html_b58cc17c0615213f4c602d12dac1ad04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산평화시장&lt;/div&gt;`)[0];
#                 popup_6ab90ae6d92fce78e02318e1aaae1d93.setContent(html_b58cc17c0615213f4c602d12dac1ad04);
#
#
#
#         marker_590add03bf00156d4a3dd98c7a6ce223.bindPopup(popup_6ab90ae6d92fce78e02318e1aaae1d93)
#         ;
#
#
#
#
#             var marker_3e256dde064235df6e49243332f59784 = L.marker(

# %%
#구역별 인구 분포 지도

# 부산 지도

busan_map = folium.Map(location=[35.17944,129.07556], tiles='Stamen Terrain', zoom_start=14)

population_df = pd.read_csv('.\data\총_구·군 인구.csv', encoding='utf-8-sig')
population_df['SIG_KOR_NM'] = population_df['SIG_KOR_NM'].astype(str)

#구역 경계

geo_path = "./busan.json"
try:
    geo_data = json.load(open(geo_path, encoding='utf-8'))
except:
    geo_data = json.load(open(geo_path, encoding='utf-8-sig'))
    

# Choropleth 시각화

folium.Choropleth(
geo_data=geo_data,
data=population_df,
key_on='feature.properties.SIG_KOR_NM',
columns=['SIG_KOR_NM', 'total_population'],
fill_color='YlGnBu',
legend_name='부산광역시 구,군 인구',).add_to(busan_map)

busan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da33d9c3d527fde51c80f5a84da23954 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da33d9c3d527fde51c80f5a84da23954&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da33d9c3d527fde51c80f5a84da23954 = L.map(
#                 &quot;map_da33d9c3d527fde51c80f5a84da23954&quot;,
#                 {
#                     center: [35.17944, 129.07556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cbe9e171d4c7e3001874f81258b18ebb = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_da33d9c3d527fde51c80f5a84da23954);
#
#
#             var choropleth_797084c21721f284c7b9b15c118af3bd = L.featureGroup(
#                 {}
#             ).addTo(map_da33d9c3d527fde51c80f5a84da23954);
#
#
#         function geo_json_52c4bac316a2b348213a92f25fd341b3_styler(feature) {
#             switch(feature.properties.SIG_CD) {
#                 case &quot;26110&quot;: case &quot;26170&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;26140&quot;: case &quot;26200&quot;: case &quot;26440&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;26230&quot;: case &quot;26350&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;26260&quot;: case &quot;26290&quot;: case &quot;26410&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;26320&quot;: case &quot;26380&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_52c4bac316a2b348213a92f25fd341b3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_52c4bac316a2b348213a92f25fd341b3 = L.geoJson(null, {
#                 onEachFeature: geo_json_52c4bac316a2b348213a92f25fd341b3_onEachFeature,
#
#                 style: geo_json_52c4bac316a2b348213a92f25fd341b3_styler,
#         });
#
#         function geo_json_52c4bac316a2b348213a92f25fd341b3_add (data) {
#             geo_json_52c4bac316a2b348213a92f25fd341b3
#                 .addData(data)
#                 .addTo(choropleth_797084c21721f284c7b9b15c118af3bd);
#         }
#             geo_json_52c4bac316a2b348213a92f25fd341b3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.032, 35.116], [129.032, 35.117], [129.032, 35.116], [129.03, 35.116], [129.028, 35.115], [129.028, 35.112], [129.028, 35.11], [129.026, 35.111], [129.024, 35.109], [129.023, 35.109], [129.021, 35.106], [129.021, 35.103], [129.021, 35.102], [129.022, 35.102], [129.024, 35.1], [129.025, 35.099], [129.025, 35.098], [129.026, 35.096], [129.029, 35.096], [129.037, 35.097], [129.038, 35.098], [129.038, 35.104], [129.041, 35.108], [129.041, 35.11], [129.042, 35.111], [129.038, 35.112], [129.036, 35.114], [129.035, 35.114], [129.034, 35.115], [129.033, 35.115], [129.033, 35.116], [129.032, 35.116]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26110&quot;, &quot;SIG_ENG_NM&quot;: &quot;Jung-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc911\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.004, 35.078], [129.006, 35.071], [129.009, 35.066], [129.012, 35.065], [129.011, 35.063], [129.008, 35.063], [129.012, 35.052], [129.015, 35.053], [129.016, 35.057], [129.018, 35.

# %%
# 부산 지도

busan_map = folium.Map(location=[35.17944,129.07556], tiles='Stamen Terrain', zoom_start=14)


# 시장 리스트를 데이터 프레임으로 변환

market_high_df = pd.read_excel('./market_list_high.xlsx', engine = "openpyxl")
market_low_df = pd.read_excel('./market_list_low.xlsx', engine = "openpyxl")
subway_df = pd.read_excel('./market_subway_list.xlsx', engine = "openpyxl")
top_20_df = pd.read_excel('./Busan_location.xlsx', engine = "openpyxl")


#구역 경계

geo_path = "./busan.json"
try:
    geo_data = json.load(open(geo_path, encoding='utf-8'))
except:
    geo_data = json.load(open(geo_path, encoding='utf-8-sig'))
    
    
# 시장, 지하철 위치 정보를 마커로 표시, top20 표시

for name, lat, lng in zip(market_high_df.시장명, market_high_df.위도, market_high_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=150),
                  icon=folium.Icon(color='pink',icon='basket-shopping', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(market_low_df.시장명, market_low_df.위도, market_low_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=150),
                  icon=folium.Icon(color='lightgray',icon='basket-shopping', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(subway_df.역명, subway_df.위도, subway_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=50, max_width=100),
                  icon=folium.Icon(color='lightgreen',icon='train-subway', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(top_20_df.시장명, top_20_df.위도, top_20_df.경도):
    folium.CircleMarker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=100),
                  radius=10, color='black').add_to(busan_map)
    

# Choropleth 시각화

folium.Choropleth(
geo_data=geo_data,
data=population_df,
key_on='feature.properties.SIG_KOR_NM',
columns=['SIG_KOR_NM', 'total_population'],
fill_color='YlGnBu',
legend_name='부산광역시 구,군 인구',).add_to(busan_map)

busan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cb994e005148dceaf8d589414310c0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cb994e005148dceaf8d589414310c0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cb994e005148dceaf8d589414310c0e = L.map(
#                 &quot;map_2cb994e005148dceaf8d589414310c0e&quot;,
#                 {
#                     center: [35.17944, 129.07556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_415ac232c4c825938892d448eb4c5b3b = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2cb994e005148dceaf8d589414310c0e);
#
#
#             var marker_ce008a39a9cc6216c03a2fc15386c7f9 = L.marker(
#                 [35.1127693, 128.9316607],
#                 {}
#             ).addTo(map_2cb994e005148dceaf8d589414310c0e);
#
#
#             var icon_de728dc39d8f2e4625f39797695ba3c9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ce008a39a9cc6216c03a2fc15386c7f9.setIcon(icon_de728dc39d8f2e4625f39797695ba3c9);
#
#
#         var popup_6189885b0942ed0923132c7eb4fa5ab2 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_52bbc6253f2010a04762e3fffb35d54f = $(`&lt;div id=&quot;html_52bbc6253f2010a04762e3fffb35d54f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;명지시장&lt;/div&gt;`)[0];
#                 popup_6189885b0942ed0923132c7eb4fa5ab2.setContent(html_52bbc6253f2010a04762e3fffb35d54f);
#
#
#
#         marker_ce008a39a9cc6216c03a2fc15386c7f9.bindPopup(popup_6189885b0942ed0923132c7eb4fa5ab2)
#         ;
#
#
#
#
#             var marker_e115f4d07e6956b6b332f5c3c6b9caf8 = L.marker(
#                 [35.0966394, 129.0305933],
#                 {}
#             ).addTo(map_2cb994e005148dceaf8d589414310c0e);
#
#
#             var icon_2149e1770edf79728c222347b54e19b6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e115f4d07e6956b6b332f5c3c6b9caf8.setIcon(icon_2149e1770edf79728c222347b54e19b6);
#
#
#         var popup_93863392420c2874ae74853cbe30409b = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_a437c4da727017cd3d3747aa0f5c47f6 = $(`&lt;div id=&quot;html_a437c4da727017cd3d3747aa0f5c47f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;자갈치시장&lt;/div&gt;`)[0];
#                 popup_93863392420c2874ae74853cbe30409b.setContent(html_a437c4da727017cd3d3747aa0f5c47f6);
#
#
#
#         marker_e115f4d07e6956b6b332f5c3c6b9caf8.bindPopup(popup_93863392420c2874ae74853cbe30409b)
#         ;
#
#
#
#
#             var marker_6e4932e57a59a66836e792195ab78a67 = L.marker(
#                 [35.1416917, 129.0606173],
#                 {}
#             ).addTo(map_2cb994e005148dceaf8d589414310c0e);
#
#
#             var icon_ad2f27527169e90628f58a81037a8903 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6e4932e57a59a66836e792195ab78a67.setIcon(icon_ad2f27527169e90628f58a81037a8903);
#
#
#         var popup_41ccf2199d6609f7ab557be3251da013 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_30d5a72cff04b8fbd18d75aa0bc52cb6 = $(`&lt;div id=&quot;html_30d5a72cff04b8fbd18d75aa0bc52cb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산평화시장&lt;/div&gt;`)[0];
#                 popup_41ccf2199d6609f7ab557be3251da013.setContent(html_30d5a72cff04b8fbd18d75aa0bc52cb6);
#
#
#
#         marker_6e4932e57a59a66836e792195ab78a67.bindPopup(popup_41ccf2199d6609f7ab557be3251da
