# %%
import folium
import pandas as pd
import csv
import json

# 부산 지도 만들기
busan_map =folium.Map(location=[35.17944,129.07556], tiles='Stamen Terrain', zoom_start=14)

busan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc217d9a6de727686024ec431d0bb54a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc217d9a6de727686024ec431d0bb54a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc217d9a6de727686024ec431d0bb54a = L.map(
#                 &quot;map_dc217d9a6de727686024ec431d0bb54a&quot;,
#                 {
#                     center: [35.17944, 129.07556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_253edaf0c0e2f2b1d945e7146803406b = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dc217d9a6de727686024ec431d0bb54a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 시장 리스트를 데이터 프레임으로 변환

market_high_df = pd.read_excel('./project/market_list_high.xlsx', engine = "openpyxl")
market_low_df = pd.read_excel('./project/market_list_low.xlsx', engine = "openpyxl")
subway_df = pd.read_excel('./project/market_subway_list.xlsx', engine = "openpyxl")
top_20_df = pd.read_excel('./project/Busan_location.xlsx', engine = "openpyxl")

# %%
# 시장, 지하철 위치 정보를 마커로 표시, top20 표시

for name, lat, lng in zip(market_high_df.시장명, market_high_df.위도, market_high_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=150),
                  icon=folium.Icon(color='pink',icon='basket-shopping', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(market_low_df.시장명, market_low_df.위도, market_low_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=150),
                  icon=folium.Icon(color='lightgray',icon='basket-shopping', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(subway_df.역명, subway_df.위도, subway_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=50, max_width=100),
                  icon=folium.Icon(color='lightgreen',icon='train-subway', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(top_20_df.시장명, top_20_df.위도, top_20_df.경도):
    folium.CircleMarker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=100),
                  radius=10, color='black').add_to(busan_map)
    
busan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc217d9a6de727686024ec431d0bb54a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc217d9a6de727686024ec431d0bb54a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc217d9a6de727686024ec431d0bb54a = L.map(
#                 &quot;map_dc217d9a6de727686024ec431d0bb54a&quot;,
#                 {
#                     center: [35.17944, 129.07556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_253edaf0c0e2f2b1d945e7146803406b = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dc217d9a6de727686024ec431d0bb54a);
#
#
#             var marker_c9fbca0e1b552a92ca38d2385353e3fd = L.marker(
#                 [35.1127693, 128.9316607],
#                 {}
#             ).addTo(map_dc217d9a6de727686024ec431d0bb54a);
#
#
#             var icon_a9f9c364ec711296436ea73f49e9dec9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c9fbca0e1b552a92ca38d2385353e3fd.setIcon(icon_a9f9c364ec711296436ea73f49e9dec9);
#
#
#         var popup_d0c0f47536a21566723ed6ac3c3f2611 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_a424a04cefc1733924594a8a44a29dae = $(`&lt;div id=&quot;html_a424a04cefc1733924594a8a44a29dae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;명지시장&lt;/div&gt;`)[0];
#                 popup_d0c0f47536a21566723ed6ac3c3f2611.setContent(html_a424a04cefc1733924594a8a44a29dae);
#
#
#
#         marker_c9fbca0e1b552a92ca38d2385353e3fd.bindPopup(popup_d0c0f47536a21566723ed6ac3c3f2611)
#         ;
#
#
#
#
#             var marker_94d4f3d3590dcc8a25128febf56ba5d8 = L.marker(
#                 [35.0966394, 129.0305933],
#                 {}
#             ).addTo(map_dc217d9a6de727686024ec431d0bb54a);
#
#
#             var icon_539b09b0db64107b561bfb49bdca4157 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_94d4f3d3590dcc8a25128febf56ba5d8.setIcon(icon_539b09b0db64107b561bfb49bdca4157);
#
#
#         var popup_deb20b5e7b395bc15e503d30c6727abb = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_304c3b819c65e89a45a3d5a1347f08c5 = $(`&lt;div id=&quot;html_304c3b819c65e89a45a3d5a1347f08c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;자갈치시장&lt;/div&gt;`)[0];
#                 popup_deb20b5e7b395bc15e503d30c6727abb.setContent(html_304c3b819c65e89a45a3d5a1347f08c5);
#
#
#
#         marker_94d4f3d3590dcc8a25128febf56ba5d8.bindPopup(popup_deb20b5e7b395bc15e503d30c6727abb)
#         ;
#
#
#
#
#             var marker_fb3e0e69681f2effa56a125e317aeeaf = L.marker(
#                 [35.1416917, 129.0606173],
#                 {}
#             ).addTo(map_dc217d9a6de727686024ec431d0bb54a);
#
#
#             var icon_f551501c855138f9184425cc6019b882 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fb3e0e69681f2effa56a125e317aeeaf.setIcon(icon_f551501c855138f9184425cc6019b882);
#
#
#         var popup_139a86d9d407ca3bd82797b5f35e68f5 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_8920085edbe5afbfa79eb1d0390899ab = $(`&lt;div id=&quot;html_8920085edbe5afbfa79eb1d0390899ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산평화시장&lt;/div&gt;`)[0];
#                 popup_139a86d9d407ca3bd82797b5f35e68f5.setContent(html_8920085edbe5afbfa79eb1d0390899ab);
#
#
#
#         marker_fb3e0e69681f2effa56a125e317aeeaf.bindPopup(popup_139a86d9d407ca3bd82797b5f35e68f5)
#         ;
#
#
#
#
#             var marker_ca7e1f26d35018c248bcce27722ba2d0 = L.marker(

# %%
#구역별 인구 분포 지도

# 부산 지도

busan_map = folium.Map(location=[35.17944,129.07556], tiles='Stamen Terrain', zoom_start=14)

population_df = pd.read_csv('.\project\data\총_구·군 인구.csv', encoding='utf-8-sig')
population_df['SIG_KOR_NM'] = population_df['SIG_KOR_NM'].astype(str)

#구역 경계

geo_path = "./project/busan.json"
try:
    geo_data = json.load(open(geo_path, encoding='utf-8'))
except:
    geo_data = json.load(open(geo_path, encoding='utf-8-sig'))
    

# Choropleth 시각화

folium.Choropleth(
geo_data=geo_data,
data=population_df,
key_on='feature.properties.SIG_KOR_NM',
columns=['SIG_KOR_NM', 'total_population'],
fill_color='YlGnBu',
legend_name='부산광역시 구,군 인구',).add_to(busan_map)

busan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5f5ccfc62211fc496e195a0b5fdb25d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5f5ccfc62211fc496e195a0b5fdb25d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5f5ccfc62211fc496e195a0b5fdb25d = L.map(
#                 &quot;map_e5f5ccfc62211fc496e195a0b5fdb25d&quot;,
#                 {
#                     center: [35.17944, 129.07556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e00390ab09001fa1c92f0ffab22c9dc1 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e5f5ccfc62211fc496e195a0b5fdb25d);
#
#
#             var choropleth_86c304a5571fac13bebd2cb0d1bfb4f3 = L.featureGroup(
#                 {}
#             ).addTo(map_e5f5ccfc62211fc496e195a0b5fdb25d);
#
#
#         function geo_json_a2438b62f521d1f88a7646f69c6464f8_styler(feature) {
#             switch(feature.properties.SIG_CD) {
#                 case &quot;26110&quot;: case &quot;26170&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;26140&quot;: case &quot;26200&quot;: case &quot;26440&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;26230&quot;: case &quot;26350&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;26260&quot;: case &quot;26290&quot;: case &quot;26410&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;26320&quot;: case &quot;26380&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a2438b62f521d1f88a7646f69c6464f8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a2438b62f521d1f88a7646f69c6464f8 = L.geoJson(null, {
#                 onEachFeature: geo_json_a2438b62f521d1f88a7646f69c6464f8_onEachFeature,
#
#                 style: geo_json_a2438b62f521d1f88a7646f69c6464f8_styler,
#         });
#
#         function geo_json_a2438b62f521d1f88a7646f69c6464f8_add (data) {
#             geo_json_a2438b62f521d1f88a7646f69c6464f8
#                 .addData(data)
#                 .addTo(choropleth_86c304a5571fac13bebd2cb0d1bfb4f3);
#         }
#             geo_json_a2438b62f521d1f88a7646f69c6464f8_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.032, 35.116], [129.032, 35.117], [129.032, 35.116], [129.03, 35.116], [129.028, 35.115], [129.028, 35.112], [129.028, 35.11], [129.026, 35.111], [129.024, 35.109], [129.023, 35.109], [129.021, 35.106], [129.021, 35.103], [129.021, 35.102], [129.022, 35.102], [129.024, 35.1], [129.025, 35.099], [129.025, 35.098], [129.026, 35.096], [129.029, 35.096], [129.037, 35.097], [129.038, 35.098], [129.038, 35.104], [129.041, 35.108], [129.041, 35.11], [129.042, 35.111], [129.038, 35.112], [129.036, 35.114], [129.035, 35.114], [129.034, 35.115], [129.033, 35.115], [129.033, 35.116], [129.032, 35.116]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;SIG_CD&quot;: &quot;26110&quot;, &quot;SIG_ENG_NM&quot;: &quot;Jung-gu&quot;, &quot;SIG_KOR_NM&quot;: &quot;\uc911\uad6c&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[129.004, 35.078], [129.006, 35.071], [129.009, 35.066], [129.012, 35.065], [129.011, 35.063], [129.008, 35.063], [129.012, 35.052], [129.015, 35.053], [129.016, 35.057], [129.018, 35.

# %%
# 부산 지도

busan_map = folium.Map(location=[35.17944,129.07556], tiles='Stamen Terrain', zoom_start=14)


# 시장 리스트를 데이터 프레임으로 변환

market_high_df = pd.read_excel('./project/market_list_high.xlsx', engine = "openpyxl")
market_low_df = pd.read_excel('./project/market_list_low.xlsx', engine = "openpyxl")
subway_df = pd.read_excel('./project/market_subway_list.xlsx', engine = "openpyxl")
top_20_df = pd.read_excel('./project/Busan_location.xlsx', engine = "openpyxl")


#구역 경계

geo_path = "./project/busan.json"
try:
    geo_data = json.load(open(geo_path, encoding='utf-8'))
except:
    geo_data = json.load(open(geo_path, encoding='utf-8-sig'))
    
    
# 시장, 지하철 위치 정보를 마커로 표시, top20 표시

for name, lat, lng in zip(market_high_df.시장명, market_high_df.위도, market_high_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=150),
                  icon=folium.Icon(color='pink',icon='basket-shopping', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(market_low_df.시장명, market_low_df.위도, market_low_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=150),
                  icon=folium.Icon(color='lightgray',icon='basket-shopping', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(subway_df.역명, subway_df.위도, subway_df.경도):
    folium.Marker([lat, lng], popup=folium.Popup(name, min_width=50, max_width=100),
                  icon=folium.Icon(color='lightgreen',icon='train-subway', prefix='fa')).add_to(busan_map)

for name, lat, lng in zip(top_20_df.시장명, top_20_df.위도, top_20_df.경도):
    folium.CircleMarker([lat, lng], popup=folium.Popup(name, min_width=80, max_width=100),
                  radius=10, color='black').add_to(busan_map)
    

# Choropleth 시각화

folium.Choropleth(
geo_data=geo_data,
data=population_df,
key_on='feature.properties.SIG_KOR_NM',
columns=['SIG_KOR_NM', 'total_population'],
fill_color='YlGnBu',
legend_name='부산광역시 구,군 인구',).add_to(busan_map)

busan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf50c8f8dbd79e5c8f3c40f323577d9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf50c8f8dbd79e5c8f3c40f323577d9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf50c8f8dbd79e5c8f3c40f323577d9e = L.map(
#                 &quot;map_cf50c8f8dbd79e5c8f3c40f323577d9e&quot;,
#                 {
#                     center: [35.17944, 129.07556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e12deb331d7875a92fd1f327bd477f4b = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cf50c8f8dbd79e5c8f3c40f323577d9e);
#
#
#             var marker_61db8f4e562f3cda57622f3fff30c419 = L.marker(
#                 [35.1127693, 128.9316607],
#                 {}
#             ).addTo(map_cf50c8f8dbd79e5c8f3c40f323577d9e);
#
#
#             var icon_42ceb0adc4279aa694d1c5c2d356fea1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_61db8f4e562f3cda57622f3fff30c419.setIcon(icon_42ceb0adc4279aa694d1c5c2d356fea1);
#
#
#         var popup_6447804d7fac6bc6cb5b2c136ff037f3 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_6eac48d3245667d605064ef5f2a4f5ac = $(`&lt;div id=&quot;html_6eac48d3245667d605064ef5f2a4f5ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;명지시장&lt;/div&gt;`)[0];
#                 popup_6447804d7fac6bc6cb5b2c136ff037f3.setContent(html_6eac48d3245667d605064ef5f2a4f5ac);
#
#
#
#         marker_61db8f4e562f3cda57622f3fff30c419.bindPopup(popup_6447804d7fac6bc6cb5b2c136ff037f3)
#         ;
#
#
#
#
#             var marker_a32f21ef7de3f89d85cd9cc5a4eafb0d = L.marker(
#                 [35.0966394, 129.0305933],
#                 {}
#             ).addTo(map_cf50c8f8dbd79e5c8f3c40f323577d9e);
#
#
#             var icon_0340fe97f6f610d165da6ab85897b4fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a32f21ef7de3f89d85cd9cc5a4eafb0d.setIcon(icon_0340fe97f6f610d165da6ab85897b4fa);
#
#
#         var popup_5deeaefb5ce6f75f5f114ed190ab8a18 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_9d27f84871d5305aeed2a3969e1b55e6 = $(`&lt;div id=&quot;html_9d27f84871d5305aeed2a3969e1b55e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;자갈치시장&lt;/div&gt;`)[0];
#                 popup_5deeaefb5ce6f75f5f114ed190ab8a18.setContent(html_9d27f84871d5305aeed2a3969e1b55e6);
#
#
#
#         marker_a32f21ef7de3f89d85cd9cc5a4eafb0d.bindPopup(popup_5deeaefb5ce6f75f5f114ed190ab8a18)
#         ;
#
#
#
#
#             var marker_aa326326f5d1bde3444c0237b73cca52 = L.marker(
#                 [35.1416917, 129.0606173],
#                 {}
#             ).addTo(map_cf50c8f8dbd79e5c8f3c40f323577d9e);
#
#
#             var icon_eb0bc9b03780825c6de535a9eb615a8d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;basket-shopping&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_aa326326f5d1bde3444c0237b73cca52.setIcon(icon_eb0bc9b03780825c6de535a9eb615a8d);
#
#
#         var popup_54d5fa68187ccff7ccd9bc2be1865771 = L.popup({&quot;maxWidth&quot;: 150, &quot;minWidth&quot;: 80});
#
#
#
#                 var html_cfa1d0bcb4e1b7c3a3f4c15711142492 = $(`&lt;div id=&quot;html_cfa1d0bcb4e1b7c3a3f4c15711142492&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산평화시장&lt;/div&gt;`)[0];
#                 popup_54d5fa68187ccff7ccd9bc2be1865771.setContent(html_cfa1d0bcb4e1b7c3a3f4c15711142492);
#
#
#
#         marker_aa326326f5d1bde3444c0237b73cca52.bindPopup(popup_54d5fa68187ccff7ccd9bc2be1865
